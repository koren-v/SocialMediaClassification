# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp /content/drive/'My Drive'/kaggle.json .

# %%
# !ls
# Out:
# cache_dir  kaggle.json	runs	     sample_submission.csv  test.csv
# drive	   outputs	sample_data  sub.csv		    train.csv

# %%
# !mkdir ~/.kaggle
# !mv kaggle.json ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !kaggle competitions download -c nlp-getting-started
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# test.csv: Skipping, found more recently modified local copy (use --force to force download)
# sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# train.csv: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !pip install simpletransformers==0.19.2
# Out:
# Requirement already satisfied: simpletransformers==0.19.2 in /usr/local/lib/python3.6/dist-packages (0.19.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from simpletransformers==0.19.2) (4.28.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.6/dist-packages (from simpletransformers==0.19.2) (2.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from simpletransformers==0.19.2) (0.22.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from simpletransformers==0.19.2) (2019.12.20)
# Requirement already satisfied: tensorboardx in /usr/local/lib/python3.6/dist-packages (from simpletransformers==0.19.2) (2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from simpletransformers==0.19.2) (1.17.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from simpletransformers==0.19.2) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from simpletransformers==0.19.2) (2.21.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from simpletransformers==0.19.2) (0.25.3)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.6/dist-packages (from simpletransformers==0.19.2) (0.0.12)
# Requirement already satisfied: wandb in /usr/local/lib/python3.6/dist-packages (from simpletransformers==0.19.2) (0.8.24)
# Requirement already satisfied: tokenizers==0.0.11 in /usr/local/lib/python3.6/dist-packages (from transformers->simpletransformers==0.19.2) (0.0.11)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from transformers->simpletransformers==0.19.2) (1.11.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers->simpletransformers==0.19.2) (3.0.12)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.6/dist-packages (from transformers->simpletransformers==0.19.2) (0.1.85)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers->simpletransformers==0.19.2) (0.0.38)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->simpletransformers==0.19.2) (0.14.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardx->simpletransformers==0.19.2) (1.12.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardx->simpletransformers==0.19.2) (3.10.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->simpletransformers==0.19.2) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->simpletransformers==0.19.2) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->simpletransformers==0.19.2) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->simpletransformers==0.19.2) (3.0.4)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->simpletransformers==0.19.2) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->simpletransformers==0.19.2) (2.6.1)
# Requirement already satisfied: Keras>=2.2.4 in /usr/local/lib/python3.6/dist-packages (from seqeval->simpletransformers==0.19.2) (2.2.5)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb->simpletransformers==0.19.2) (5.4.8)
# Requirement already satisfied: configparser>=3.8.1 in /usr/local/lib/python3.6/dist-packages (from wandb->simpletransformers==0.19.2) (4.0.2)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.6/dist-packages (from wandb->simpletransformers==0.19.2) (7.352.0)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.6/dist-packages (from wandb->simpletransformers==0.19.2) (0.5.0)
# Requirement already satisfied: sentry-sdk>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from wandb->simpletransformers==0.19.2) (0.14.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from wandb->simpletransformers==0.19.2) (0.4.0)
# Requirement already satisfied: subprocess32>=3.5.3 in /usr/local/lib/python3.6/dist-packages (from wandb->simpletransformers==0.19.2) (3.5.4)
# Requirement already satisfied: watchdog>=0.8.3 in /usr/local/lib/python3.6/dist-packages (from wandb->simpletransformers==0.19.2) (0.10.1)
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.6/dist-packages (from wandb->simpletransformers==0.19.2) (7.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.6/dist-packages (from wandb->simpletransformers==0.19.2) (3.13)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb->simpletransformers==0.19.2) (3.0.5)
# Requirement already satisfied: gql==0.2.0 in /usr/local/lib/python3.6/dist-packages (from wandb->simpletransformers==0.19.2) (0.2.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers->simpletransformers==0.19.2) (0.3.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers->simpletransformers==0.19.2) (0.9.4)
# Requirement already satisfied: botocore<1.15.0,>=1.14.9 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers->simpletransformers==0.19.2) (1.14.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorboardx->simpletransformers==0.19.2) (45.1.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval->simpletransformers==0.19.2) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval->simpletransformers==0.19.2) (1.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval->simpletransformers==0.19.2) (2.8.0)
# Requirement already satisfied: pathtools>=0.1.1 in /usr/local/lib/python3.6/dist-packages (from watchdog>=0.8.3->wandb->simpletransformers==0.19.2) (0.1.2)
# Requirement already satisfied: gitdb2>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from GitPython>=1.0.0->wandb->simpletransformers==0.19.2) (2.0.6)
# Requirement already satisfied: graphql-core<2,>=0.5.0 in /usr/local/lib/python3.6/dist-packages (from gql==0.2.0->wandb->simpletransformers==0.19.2) (1.1)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.6/dist-packages (from gql==0.2.0->wandb->simpletransformers==0.19.2) (2.3)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.15.0,>=1.14.9->boto3->transformers->simpletransformers==0.19.2) (0.15.2)
# Requirement already satisfied: smmap2>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from gitdb2>=2.0.0->GitPython>=1.0.0->wandb->simpletransformers==0.19.2) (2.0.5)

# %%
import os, re, string
import random

import numpy as np
import pandas as pd
import sklearn
from scipy.special import softmax
import gc

import torch

from simpletransformers.classification import ClassificationModel
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# Let's have a look at our data

# %%
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")
train_data.head()
# Out:
#    id keyword  ...                                               text target
# 0   1     NaN  ...  Our Deeds are the Reason of this #earthquake M...      1
# 1   4     NaN  ...             Forest fire near La Ronge Sask. Canada      1
# 2   5     NaN  ...  All residents asked to 'shelter in place' are ...      1
# 3   6     NaN  ...  13,000 people receive #wildfires evacuation or...      1
# 4   7     NaN  ...  Just got sent this photo from Ruby #Alaska as ...      1
#
# [5 rows x 5 columns]

# %% [markdown]
# During experiments I find that removing stopwords, lemmatization, removing urls, removing emojis just leads to deterioration of the model's performance. So I will use lowercasing and will stay just letters:

# %%
train_data['text']=train_data['text'].str.lower()
test_data['text']=test_data['text'].str.lower()

# %%
train_data['text']=train_data['text'].str.replace("[^a-z]", " ")
test_data['text']=test_data['text'].str.replace("[^a-z]", " ")

# %% [markdown]
# Leave only the necessary columns

# %%
train_data = train_data[['text', 'target']]
test_data = test_data[['text']]

# %% [markdown]
# Get all default arguments:

# %%
bert_uncased = ClassificationModel('bert', 'bert-base-uncased') 

bert_uncased.args
# Out:
# {'adam_epsilon': 1e-08,
#  'best_model_dir': 'outputs/best_model',
#  'cache_dir': 'cache_dir/',
#  'do_lower_case': False,
#  'early_stopping_delta': 0,
#  'early_stopping_patience': 3,
#  'eval_batch_size': 8,
#  'evaluate_during_training': False,
#  'evaluate_during_training_steps': 2000,
#  'evaluate_during_training_verbose': False,
#  'fp16': True,
#  'fp16_opt_level': 'O1',
#  'gradient_accumulation_steps': 1,
#  'learning_rate': 4e-05,
#  'logging_steps': 50,
#  'max_grad_norm': 1.0,
#  'max_seq_length': 128,
#  'model_name': 'bert-base-uncased',
#  'model_type': 'bert',
#  'n_gpu': 1,
#  'no_cache': False,
#  'num_train_epochs': 1,
#  'output_dir': 'outputs/',
#  'overwrite_output_dir': False,
#  'process_count': 1,
#  'regression': False,
#  'reprocess_input_data': False,
#  'save_eval_checkpoints': True,
#  'save_model_every_epoch': True,
#  'save_steps': 2000,
#  'silent': False,
#  'sliding_window': False,
#  'stride': 0.8,
#  'tensorboard_dir': None,
#  'tie_value': 1,
#  'train_batch_size': 8,
#  'use_cached_eval_features': True,
#  'use_early_stopping': False,
#  'use_multiprocessing': True,
#  'wandb_kwargs': {},
#  'wandb_project': None,
#  'warmup_ratio': 0.06,
#  'warmup_steps': 0,
#  'weight_decay': 0}

# %% [markdown]
# Let's change some of them to train faster and get better score:

# %%
custom_args = {'fp16': False, # not using mixed precision 
               'train_batch_size': 16,
               'gradient_accumulation_steps': 2,
               'learning_rate': 1e-05,
               'overwrite_output_dir': True,
               'num_train_epochs': 3,
               'use_early_stopping': True,
               'max_seq_length': 50,
               'evaluate_during_training_verbose': True}

# %%
def model(features, n_folds = 5):

    k_fold = StratifiedKFold(n_splits=n_folds, shuffle=True)
    results = []

    out_of_fold = np.zeros(features.to_numpy().shape[0])

    for train_index, val_index in k_fold.split(features, features['target']):
      
        train_df = features.iloc[train_index]
        val_df = features.iloc[val_index]
    
        model = ClassificationModel('bert', 'bert-base-uncased', args=custom_args) 
        model.train_model(train_df)

        result, model_outputs, _ = model.eval_model(val_df, f1=sklearn.metrics.f1_score)
        val_proba = softmax(model_outputs, axis=1)

        out_of_fold[val_index] = val_proba[:, 1]

        results.append(result['f1'])

        gc.enable()
        del train_df, val_df
        gc.collect()

    return out_of_fold, results

# %%
predictions, f1 = model(train_data)
# Out:
# Features loaded from cache at cache_dir/cached_train_bert_50_2_6090
# /usr/local/lib/python3.6/dist-packages/simpletransformers/classification/classification_model.py:237: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# HBox(children=(IntProgress(value=0, description='Epoch', max=3, style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='Current iteration', max=381, style=ProgressStyle(description_…
# Running loss: 0.450439
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:224: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# Running loss: 0.449704
# HBox(children=(IntProgress(value=0, description='Current iteration', max=381, style=ProgressStyle(description_…
# Running loss: 0.456449
# HBox(children=(IntProgress(value=0, description='Current iteration', max=381, style=ProgressStyle(description_…
# Running loss: 0.083468Training of bert model complete. Saved to outputs/.
# Features loaded from cache at cache_dir/cached_dev_bert_50_2_1523
# /usr/local/lib/python3.6/dist-packages/simpletransformers/classification/classification_model.py:567: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# HBox(children=(IntProgress(value=0, max=191), HTML(value='')))
# {'mcc': 0.6600609549357257, 'tp': 507, 'tn': 763, 'fp': 101, 'fn': 152, 'f1': 0.8003157063930546, 'eval_loss': 0.39832949029837605}
# Features loaded from cache at cache_dir/cached_train_bert_50_2_6090
# HBox(children=(IntProgress(value=0, description='Epoch', max=3, style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='Current iteration', max=381, style=ProgressStyle(description_…
# Running loss: 0.440049
# HBox(children=(IntProgress(value=0, description='Current iteration', max=381, style=ProgressStyle(description_…
# Running loss: 0.322550
# HBox(children=(IntProgress(value=0, description='Current iteration', max=381, style=ProgressStyle(description_…
# Running loss: 0.094372Training of bert model complete. Saved to outputs/.
# Features loaded from cache at cache_dir/cached_dev_bert_50_2_1523
# HBox(children=(IntProgress(value=0, max=191), HTML(value='')))
# {'mcc': 0.676585874630077, 'tp': 504, 'tn': 778, 'fp': 86, 'fn': 155, 'f1': 0.8070456365092074, 'eval_loss': 0.38327673794360373}
# Features loaded from cache at cache_dir/cached_train_bert_50_2_6090
# HBox(children=(IntProgress(value=0, description='Epoch', max=3, style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='Current iteration', max=381, style=ProgressStyle(description_…
# Running loss: 0.595385
# HBox(children=(IntProgress(value=0, description='Current iteration', max=381, style=ProgressStyle(description_…
# Running loss: 0.641631
# HBox(children=(IntProgress(value=0, description='Current iteration', max=381, style=ProgressStyle(description_…
# Running loss: 0.173651Training of bert model complete. Saved to outputs/.
# Features loaded from cache at cache_dir/cached_dev_bert_50_2_1523
# HBox(children=(IntProgress(value=0, max=191), HTML(value='')))
# {'mcc': 0.667040365917132, 'tp': 501, 'tn': 774, 'fp': 90, 'fn': 158, 'f1': 0.8016000000000001, 'eval_loss': 0.3938724779821347}
# Features loaded from cache at cache_dir/cached_train_bert_50_2_6091
# HBox(children=(IntProgress(value=0, description='Epoch', max=3, style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='Current iteration', max=381, style=ProgressStyle(description_…
# Running loss: 0.387800
# HBox(children=(IntProgress(value=0, description='Current iteration', max=381, style=ProgressStyle(description_…
# Running loss: 0.325634
# HBox(children=(IntProgress(value=0, description='Current iteration', max=381, style=ProgressStyle(description_…
# Running loss: 0.551014Training of bert model complete. Saved to outputs/.
# Features loaded from cache at cache_dir/cached_dev_bert_50_2_1522
# HBox(children=(IntProgress(value=0, max=191), HTML(value='')))
# {'mcc': 0.6475000895480004, 'tp': 504, 'tn': 757, 'fp': 122, 'fn': 139, 'f1': 0.7943262411347518, 'eval_loss': 0.4360057632804541}
# Features loaded from cache at cache_dir/cached_train_bert_50_2_6091
# HBox(children=(IntProgress(value=0, description='Epoch', max=3, style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='Current iteration', max=381, style=ProgressStyle(description_…
# Running loss: 0.366732
# HBox(children=(IntProgress(value=0, description='Current iteration', max=381, style=ProgressStyle(description_…
# Running loss: 0.414414
# HBox(children=(IntProgress(value=0, description='Current iteration', max=381, style=ProgressStyle(description_…
# Running loss: 0.366755Training of bert model complete. Saved to outputs/.
# Features loaded from cache at cache_dir/cached_dev_bert_50_2_1522
# HBox(children=(IntProgress(value=0, max=191), HTML(value='')))
# {'mcc': 0.6458147107424473, 'tp': 511, 'tn': 748, 'fp': 131, 'fn': 132, 'f1': 0.795330739299611, 'eval_loss': 0.4312085686787885}

# %% [markdown]
# Let's look again at the F1:

# %%
for i, result in enumerate(f1, 1):
    print("Fold {}: {:4f}".format(i, result))
    
print("\nMean F1: {:4f}".format(np.mean(f1)))
# Out:
# Fold 1: 0.800316
# Fold 2: 0.807046
# Fold 3: 0.801600
# Fold 4: 0.794326
# Fold 5: 0.795331
#
# Mean F1: 0.799724

# %%
prediction = train_data.copy()

prediction['bert_pred'] = predictions
prediction = prediction.drop(columns = ['target', 'text'])

# %%
prediction.head()
# Out:
#    bert_pred
# 0   0.975460
# 1   0.966836
# 2   0.821777
# 3   0.981626
# 4   0.967243

# %%
model = ClassificationModel('bert', 'bert-base-uncased', args=custom_args)
model.train_model(train_data)
_, raw_outputs = model.predict(test_data['text'])
# Out:
# Features loaded from cache at cache_dir/cached_train_bert_50_2_7613
# /usr/local/lib/python3.6/dist-packages/simpletransformers/classification/classification_model.py:237: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# HBox(children=(IntProgress(value=0, description='Epoch', max=3, style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='Current iteration', max=476, style=ProgressStyle(description_…
# Running loss: 0.595285
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:224: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# Running loss: 0.294684
# HBox(children=(IntProgress(value=0, description='Current iteration', max=476, style=ProgressStyle(description_…
# Running loss: 0.107539
# HBox(children=(IntProgress(value=0, description='Current iteration', max=476, style=ProgressStyle(description_…
# Running loss: 0.371855Training of bert model complete. Saved to outputs/.
# Features loaded from cache at cache_dir/cached_dev_bert_50_2_3263
# HBox(children=(IntProgress(value=0, max=408), HTML(value='')))

# %%
test_proba = softmax(raw_outputs, axis=1)

# %%
test_predictions = test_proba[:, 1]

# %%
test_prediction = test_data.copy()

test_prediction['bert_pred'] = test_predictions

test_prediction = test_prediction.drop(columns = ['text'])

# %%
test_prediction.head()
# Out:
#    bert_pred
# 0   0.972604
# 1   0.981176
# 2   0.982866
# 3   0.989683
# 4   0.988967

# %%
prediction.to_csv('/content/drive/My Drive/tweeter/train_predictions_bert.csv', index_label='idx')
test_prediction.to_csv('/content/drive/My Drive/tweeter/test_predictions_bert.csv', index_label='idx')

# %% [markdown]
# тренуэ на всих даних

# %%
model = ClassificationModel('bert', 'bert-base-uncased', args=custom_args) 
model.train_model(train_data)
# Out:
# Converting to features started. Cache is not used.
# /usr/local/lib/python3.6/dist-packages/simpletransformers/classification/classification_model.py:237: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# HBox(children=(IntProgress(value=0, max=7613), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='Epoch', max=3, style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='Current iteration', max=476, style=ProgressStyle(description_…
# Running loss: 0.690791
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:224: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# Running loss: 0.558720
# HBox(children=(IntProgress(value=0, description='Current iteration', max=476, style=ProgressStyle(description_…
# Running loss: 0.613014
# HBox(children=(IntProgress(value=0, description='Current iteration', max=476, style=ProgressStyle(description_…
# Running loss: 0.577653
# Training of bert model complete. Saved to outputs/.

# %%
predictions, raw_outputs = model.predict(test_data['text'])

sample_submission = pd.read_csv("sample_submission.csv")
sample_submission["target"] = predictions
sample_submission.to_csv("sub.csv", index=False)
# Out:
# Features loaded from cache at cache_dir/cached_dev_bert_50_2_3263
# HBox(children=(IntProgress(value=0, max=408), HTML(value='')))

# %%
# !kaggle competitions submit -c nlp-getting-started -f sub.csv -m "Message"
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# 100% 22.2k/22.2k [00:00<00:00, 23.5kB/s]
# Successfully submitted to Real or Not? NLP with Disaster Tweets
